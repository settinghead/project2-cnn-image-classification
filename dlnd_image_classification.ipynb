# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/cifar/cifar-10-python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 2227
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 2227:
# Image - Min Value: 22 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x / 255.0 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
one_hot_lookup = np.eye(10)

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    return one_hot_lookup[x]
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # DONE: Implement Function
    return tf.placeholder(dtype=tf.float32, name="x", shape=[None] + list(image_shape))


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # DONE: Implement Function
    return tf.placeholder(dtype=tf.float32, name="y", shape=[None, n_classes])


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return  tf.placeholder(dtype=tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # DONE: Implement Function
    
    [_,_,_,input_depth] = x_tensor.get_shape().as_list()
    weights = tf.Variable(tf.truncated_normal([*conv_ksize, input_depth, conv_num_outputs], stddev=0.01))
    bias = tf.Variable(full([conv_num_outputs], 0.01), dtype=tf.float32)
    conv_layer = tf.nn.conv2d(x_tensor, weights, strides= [1, *conv_strides , 1], padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.max_pool(conv_layer, ksize=[1, * pool_ksize, 1], strides=[1, *pool_strides, 1], padding='SAME')
    conv_layer = tf.nn.relu(conv_layer)
    return conv_layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
from numpy import prod

def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # DONE: Implement Function
    image_size = prod(x_tensor.get_shape().as_list()[1:])
    flattened = tf.reshape(x_tensor, [-1, image_size])
    return flattened


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
from numpy import prod, full

def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # DONE: Implement Function
    input_size = prod(x_tensor.get_shape().as_list()[1:])
    weights = tf.Variable(tf.truncated_normal([input_size, num_outputs], stddev=0.01))
    bias = tf.Variable(full([num_outputs], 0.01), dtype=tf.float32)
    fully_c = tf.add(tf.matmul(x_tensor, weights), bias)
    fully_c = tf.nn.relu(fully_c)
    return fully_c


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    input_size = prod(x_tensor.get_shape().as_list()[1:])
    weights = tf.Variable(tf.truncated_normal([input_size, num_outputs], stddev=0.02))
    bias = tf.Variable(tf.truncated_normal([num_outputs], stddev=0.02))
    output = tf.add(tf.matmul(x_tensor, weights), bias)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
        
    conv_num_outputs = [32, 48, 72]
    conv_ksizes = [(3,3), (3,3), (3,3)]
    
    curr_layer = x
    for i in range(0, len(conv_num_outputs)):
        curr_layer = conv2d_maxpool(
            x, 
            conv_num_outputs[i], 
            conv_ksizes[i], 
            conv_strides=[1, 1],
            pool_ksize=[2,2],
            pool_strides=[1,1]
        )

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    curr_layer = flatten(curr_layer)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    fc_num_outputs = [800,500,200]
    for num_output in fc_num_outputs:
        curr_layer = fully_conn(curr_layer, num_output)
        curr_layer = tf.nn.dropout(curr_layer, keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    
    # TODO: return output
    curr_layer = output(curr_layer, 10)
    
    return curr_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # DONE: Implement Function
    session.run(optimizer, feed_dict = { x: feature_batch, y: label_batch, keep_prob: keep_probability })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # DONE: Implement Function
    loss = sess.run(cost, feed_dict={ x: feature_batch, y: label_batch, keep_prob: 1.0 })
    v_acc = session.run(accuracy, feed_dict = { x: valid_features, y: valid_labels, keep_prob: 1.0 })
    print('Loss: ', loss)
    print('Validation accuracy: ', v_acc)

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# DONE: Tune Parameters
epochs = 100
batch_size = 1000
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:  2.26227
# Validation accuracy:  0.1174
# Epoch  2, CIFAR-10 Batch 1:  Loss:  2.24087
# Validation accuracy:  0.1482
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-189-0ebd1bbc35ad> in <module>()
#      11         batch_i = 1
#      12         for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
# ---> 13             train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
#      14         print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
#      15         print_stats(sess, batch_features, batch_labels, cost, accuracy)
#
# <ipython-input-166-44769fc137a1> in train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch)
#       9     """
#      10     # DONE: Implement Function
# ---> 11     session.run(optimizer, feed_dict = { x: feature_batch, y: label_batch, keep_prob: keep_probability })
#      12
#      13
#
# C:\Anaconda2\envs\py3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Anaconda2\envs\py3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# C:\Anaconda2\envs\py3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# C:\Anaconda2\envs\py3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# C:\Anaconda2\envs\py3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:  2.2429
# Validation accuracy:  0.141
# Epoch  1, CIFAR-10 Batch 2:  Loss:  2.11477
# Validation accuracy:  0.1646
# Epoch  1, CIFAR-10 Batch 3:  Loss:  2.06687
# Validation accuracy:  0.2138
# Epoch  1, CIFAR-10 Batch 4:  Loss:  1.99458
# Validation accuracy:  0.2366
# Epoch  1, CIFAR-10 Batch 5:  Loss:  1.94432
# Validation accuracy:  0.2702
# Epoch  2, CIFAR-10 Batch 1:  Loss:  1
# Epoch 43, CIFAR-10 Batch 4:  Loss:  0.0605286
# Validation accuracy:  0.6618
# Epoch 43, CIFAR-10 Batch 5:  Loss:  0.0572644
# Validation accuracy:  0.6564
# Epoch 44, CIFAR-10 Batch 1:  Loss:  0.061399
# Validation accuracy:  0.6632
# Epoch 44, CIFAR-10 Batch 2:  Loss:  0.0692355
# Validation accuracy:  0.6558
# Epoch 44, CIFAR-10 Batch 3:  Loss:  0.0669241
# Validation accuracy:  0.6532
# Epoch 44, CIFAR-10 Batch 4:  Loss:  0.0594066
# Validation accuracy:  0.6598
# Epoch 44, CIFAR-10 Batch 5:  Loss:  0.0579223
# Validation accuracy:  0.6612
# Epoch 45, CIFAR-10 Batch 1:  Loss:  0.0526838
# Validation accuracy:  0.6574
# Epoch 45, CIFAR-10 Batch 2:  Loss:  0.0660498
# Validation accuracy:  0.66
# Epoch 45, CIFAR-10 Batch 3:  Loss:  0.0551982
# Validation accuracy:  0.6614
# Epoch 45, CIFAR-10 Batch 4:  Loss:  0.0576106
# Validation accuracy:  0.6592
# Epoch 45, CIFAR-10 Batch 5:  Loss:  0.057298
# Validation accuracy:  0.6636
# Epoch 46, CIFAR-10 Batch 1:  Loss:  0.0516455
# Validation accuracy:  0.6656
# Epoch 46, CIFAR-10 Batch 2:  Loss:  0.0545972
# Validation accuracy:  0.664
# Epoch 46, CIFAR-10 Batch 3:  Loss:  0.0569545
# Validation accuracy:  0.6562
# Epoch 46, CIFAR-10 Batch 4:  Loss:  0.0525933
# Validation accuracy:  0.6534
# Epoch 46, CIFAR-10 Batch 5:  Loss:  0.0473679
# Validation accuracy:  0.6526
# Epoch 47, CIFAR-10 Batch 1:  Loss:  0.0488056
# Validation accuracy:  0.6574
# Epoch 47, CIFAR-10 Batch 2:  Loss:  0.0505147
# Validation accuracy:  0.6536
# Epoch 47, CIFAR-10 Batch 3:  Loss:  0.0461006
# Validation accuracy:  0.6624
# Epoch 47, CIFAR-10 Batch 4:  Loss:  0.0506447
# Validation accuracy:  0.6548
# Epoch 47, CIFAR-10 Batch 5:  Loss:  0.0453575
# Validation accuracy:  0.6642
# Epoch 48, CIFAR-10 Batch 1:  Loss:  0.0478185
# Validation accuracy:  0.6584
# Epoch 48, CIFAR-10 Batch 2:  Loss:  0.0483077
# Validation accuracy:  0.6616
# Epoch 48, CIFAR-10 Batch 3:  Loss:  0.0408176
# Validation accuracy:  0.6652
# Epoch 48, CIFAR-10 Batch 4:  Loss:  0.0407764
# Validation accuracy:  0.6582
# Epoch 48, CIFAR-10 Batch 5:  Loss:  0.0449963
# Validation accuracy:  0.656
# Epoch 49, CIFAR-10 Batch 1:  Loss:  0.0410279
# Validation accuracy:  0.6612
# Epoch 49, CIFAR-10 Batch 2:  Loss:  0.0469551
# Validation accuracy:  0.6582
# Epoch 49, CIFAR-10 Batch 3:  Loss:  0.0397357
# Validation accuracy:  0.6644
# Epoch 49, CIFAR-10 Batch 4:  Loss:  0.0360864
# Validation accuracy:  0.6572
# Epoch 49, CIFAR-10 Batch 5:  Loss:  0.0351769
# Validation accuracy:  0.6562
# Epoch 50, CIFAR-10 Batch 1:  Loss:  0.0354478
# Validation accuracy:  0.6648
# Epoch 50, CIFAR-10 Batch 2:  Loss:  0.0413135
# Validation accuracy:  0.656
# Epoch 50, CIFAR-10 Batch 3:  Loss:  0.0349551
# Validation accuracy:  0.6678
# Epoch 50, CIFAR-10 Batch 4:  Loss:  0.03746
# Validation accuracy:  0.6586
# Epoch 50, CIFAR-10 Batch 5:  Loss:  0.0328188
# Validation accuracy:  0.6564
# Epoch 51, CIFAR-10 Batch 1:  Loss:  0.0334973
# Validation accuracy:  0.6566
# Epoch 51, CIFAR-10 Batch 2:  Loss:  0.0456143
# Validation accuracy:  0.6544
# Epoch 51, CIFAR-10 Batch 3:  Loss:  0.033338
# Validation accuracy:  0.6614
# Epoch 51, CIFAR-10 Batch 4:  Loss:  0.0311098
# Validation accuracy:  0.6644
# Epoch 51, CIFAR-10 Batch 5:  Loss:  0.0317404
# Validation accuracy:  0.6622
# Epoch 52, CIFAR-10 Batch 1:  Loss:  0.0256673
# Validation accuracy:  0.6638
# Epoch 52, CIFAR-10 Batch 2:  Loss:  0.0335968
# Validation accuracy:  0.6702
# Epoch 52, CIFAR-10 Batch 3:  Loss:  0.02948
# Validation accuracy:  0.6704
# Epoch 52, CIFAR-10 Batch 4:  Loss:  0.0325001
# Validation accuracy:  0.6604
# Epoch 52, CIFAR-10 Batch 5:  Loss:  0.027866
# Validation accuracy:  0.665
# Epoch 53, CIFAR-10 Batch 1:  Loss:  0.035546
# Validation accuracy:  0.6636
# Epoch 53, CIFAR-10 Batch 2:  Loss:  0.0424696
# Validation accuracy:  0.6678
# Epoch 53, CIFAR-10 Batch 3:  Loss:  0.0348081
# Validation accuracy:  0.6644
# Epoch 53, CIFAR-10 Batch 4:  Loss:  0.028854
# Validation accuracy:  0.6618
# Epoch 53, CIFAR-10 Batch 5:  Loss:  0.0285403
# Validation accuracy:  0.6538
# Epoch 54, CIFAR-10 Batch 1:  Loss:  0.0293607
# Validation accuracy:  0.6628
# Epoch 54, CIFAR-10 Batch 2:  Loss:  0.0328004
# Validation accuracy:  0.6668
# Epoch 54, CIFAR-10 Batch 3:  Loss:  0.0253098
# Validation accuracy:  0.6628
# Epoch 54, CIFAR-10 Batch 4:  Loss:  0.0252987
# Validation accuracy:  0.6588
# Epoch 54, CIFAR-10 Batch 5:  Loss:  0.0325599
# Validation accuracy:  0.6562
# Epoch 55, CIFAR-10 Batch 1:  Loss:  0.0284101
# Validation accuracy:  0.6638
# Epoch 55, CIFAR-10 Batch 2:  Loss:  0.0286877
# Validation accuracy:  0.6694
# Epoch 55, CIFAR-10 Batch 3:  Loss:  0.0272449
# Validation accuracy:  0.6688
# Epoch 55, CIFAR-10 Batch 4:  Loss:  0.0223982
# Validation accuracy:  0.6698
# Epoch 55, CIFAR-10 Batch 5:  Loss:  0.0224873
# Validation accuracy:  0.6666
# Epoch 56, CIFAR-10 Batch 1:  Loss:  0.0281772
# Validation accuracy:  0.6532
# Epoch 56, CIFAR-10 Batch 2:  Loss:  0.0263563
# Validation accuracy:  0.6668
# Epoch 56, CIFAR-10 Batch 3:  Loss:  0.024895
# Validation accuracy:  0.663
# Epoch 56, CIFAR-10 Batch 4:  Loss:  0.0245725
# Validation accuracy:  0.6602
# Epoch 56, CIFAR-10 Batch 5:  Loss:  0.0208239
# Validation accuracy:  0.6618
# Epoch 57, CIFAR-10 Batch 1:  Loss:  0.0250745
# Validation accuracy:  0.661
# Epoch 57, CIFAR-10 Batch 2:  Loss:  0.0264809
# Validation accuracy:  0.6628
# Epoch 57, CIFAR-10 Batch 3:  Loss:  0.0208298
# Validation accuracy:  0.6616
# Epoch 57, CIFAR-10 Batch 4:  Loss:  0.0252407
# Validation accuracy:  0.6614
# Epoch 57, CIFAR-10 Batch 5:  Loss:  0.0211527
# Validation accuracy:  0.6582
# Epoch 58, CIFAR-10 Batch 1:  Loss:  0.0213299
# Validation accuracy:  0.6592
# Epoch 58, CIFAR-10 Batch 2:  Loss:  0.0256546
# Validation accuracy:  0.6648
# Epoch 58, CIFAR-10 Batch 3:  Loss:  0.0197835
# Validation accuracy:  0.6618
# Epoch 58, CIFAR-10 Batch 4:  Loss:  0.0185404
# Validation accuracy:  0.6688
# Epoch 58, CIFAR-10 Batch 5:  Loss:  0.0209441
# Validation accuracy:  0.6646
# Epoch 59, CIFAR-10 Batch 1:  Loss:  0.0185902
# Validation accuracy:  0.6568
# Epoch 59, CIFAR-10 Batch 2:  Loss:  0.0211106
# Validation accuracy:  0.6666
# Epoch 59, CIFAR-10 Batch 3:  Loss:  0.0181521
# Validation accuracy:  0.667
# Epoch 59, CIFAR-10 Batch 4:  Loss:  0.0201093
# Validation accuracy:  0.6582
# Epoch 59, CIFAR-10 Batch 5:  Loss:  0.0189304
# Validation accuracy:  0.66
# Epoch 60, CIFAR-10 Batch 1:  Loss:  0.01952
# Validation accuracy:  0.6526
# Epoch 60, CIFAR-10 Batch 2:  Loss:  0.0226797
# Validation accuracy:  0.6636
# Epoch 60, CIFAR-10 Batch 3:  Loss:  0.0220396
# Validation accuracy:  0.6618
# Epoch 60, CIFAR-10 Batch 4:  Loss:  0.0187428
# Validation accuracy:  0.6638
# Epoch 60, CIFAR-10 Batch 5:  Loss:  0.0188502
# Validation accuracy:  0.6614
# Epoch 61, CIFAR-10 Batch 1:  Loss:  0.0139072
# Validation accuracy:  0.6696
# Epoch 61, CIFAR-10 Batch 2:  Loss:  0.0296632
# Validation accuracy:  0.6618
# Epoch 61, CIFAR-10 Batch 3:  Loss:  0.0164117
# Validation accuracy:  0.6712
# Epoch 61, CIFAR-10 Batch 4:  Loss:  0.0183705
# Validation accuracy:  0.6636
# Epoch 61, CIFAR-10 Batch 5:  Loss:  0.0137906
# Validation accuracy:  0.664
# Epoch 62, CIFAR-10 Batch 1:  Loss:  0.0141371
# Validation accuracy:  0.665
# Epoch 62, CIFAR-10 Batch 2:  Loss:  0.0237814
# Validation accuracy:  0.6628
# Epoch 62, CIFAR-10 Batch 3:  Loss:  0.0250639
# Validation accuracy:  0.6648
# Epoch 62, CIFAR-10 Batch 4:  Loss:  0.0165196
# Validation accuracy:  0.6622
# Epoch 62, CIFAR-10 Batch 5:  Loss:  0.0158698
# Validation accuracy:  0.66
# Epoch 63, CIFAR-10 Batch 1:  Loss:  0.012954
# Validation accuracy:  0.6668
# Epoch 63, CIFAR-10 Batch 2:  Loss:  0.0240888
# Validation accuracy:  0.6552
# Epoch 63, CIFAR-10 Batch 3:  Loss:  0.0134596
# Validation accuracy:  0.664
# Epoch 63, CIFAR-10 Batch 4:  Loss:  0.0128247
# Validation accuracy:  0.6628
# Epoch 63, CIFAR-10 Batch 5:  Loss:  0.0110634
# Validation accuracy:  0.6636
# Epoch 64, CIFAR-10 Batch 1:  Loss:  0.0149414
# Validation accuracy:  0.6558
# Epoch 64, CIFAR-10 Batch 2:  Loss:  0.0210637
# Validation accuracy:  0.6628
# Epoch 64, CIFAR-10 Batch 3:  Loss:  0.020306
# Validation accuracy:  0.6578
# Epoch 64, CIFAR-10 Batch 4:  Loss:  0.0176294
# Validation accuracy:  0.654
# Epoch 64, CIFAR-10 Batch 5:  Loss:  0.0118212
# Validation accuracy:  0.6648
# Epoch 65, CIFAR-10 Batch 1:  Loss:  0.0111802
# Validation accuracy:  0.6632
# Epoch 65, CIFAR-10 Batch 2:  Loss:  0.0165856
# Validation accuracy:  0.6692
# Epoch 65, CIFAR-10 Batch 3:  Loss:  0.0129782
# Validation accuracy:  0.6662
# Epoch 65, CIFAR-10 Batch 4:  Loss:  0.0179237
# Validation accuracy:  0.6598
# Epoch 65, CIFAR-10 Batch 5:  Loss:  0.0154695
# Validation accuracy:  0.6616
# Epoch 66, CIFAR-10 Batch 1:  Loss:  0.0156055
# Validation accuracy:  0.6642
# Epoch 66, CIFAR-10 Batch 2:  Loss:  0.0146924
# Validation accuracy:  0.667
# Epoch 66, CIFAR-10 Batch 3:  Loss:  0.012671
# Validation accuracy:  0.666
# Epoch 66, CIFAR-10 Batch 4:  Loss:  0.0140925
# Validation accuracy:  0.6646
# Epoch 66, CIFAR-10 Batch 5:  Loss:  0.017787
# Validation accuracy:  0.6594
# Epoch 67, CIFAR-10 Batch 1:  Loss:  0.0147307
# Validation accuracy:  0.6682
# Epoch 67, CIFAR-10 Batch 2:  Loss:  0.0142165
# Validation accuracy:  0.6654
# Epoch 67, CIFAR-10 Batch 3:  Loss:  0.0145268
# Validation accuracy:  0.667
# Epoch 67, CIFAR-10 Batch 4:  Loss:  0.0122703
# Validation accuracy:  0.6594
# Epoch 67, CIFAR-10 Batch 5:  Loss:  0.0146934
# Validation accuracy:  0.6646
# Epoch 68, CIFAR-10 Batch 1:  Loss:  0.0104393
# Validation accuracy:  0.667
# Epoch 68, CIFAR-10 Batch 2:  Loss:  0.0136759
# Validation accuracy:  0.6684
# Epoch 68, CIFAR-10 Batch 3:  Loss:  0.0114708
# Validation accuracy:  0.6688
# Epoch 68, CIFAR-10 Batch 4:  Loss:  0.011376
# Validation accuracy:  0.6608
# Epoch 68, CIFAR-10 Batch 5:  Loss:  0.0115776
# Validation accuracy:  0.6612
# Epoch 69, CIFAR-10 Batch 1:  Loss:  0.00900029
# Validation accuracy:  0.6658
# Epoch 69, CIFAR-10 Batch 2:  Loss:  0.0124054
# Validation accuracy:  0.6644
# Epoch 69, CIFAR-10 Batch 3:  Loss:  0.0100905
# Validation accuracy:  0.665
# Epoch 69, CIFAR-10 Batch 4:  Loss:  0.0129215
# Validation accuracy:  0.6644
# Epoch 69, CIFAR-10 Batch 5:  Loss:  0.0105546
# Validation accuracy:  0.6572
# Epoch 70, CIFAR-10 Batch 1:  Loss:  0.0143608
# Validation accuracy:  0.6646
# Epoch 70, CIFAR-10 Batch 2:  Loss:  0.0144829
# Validation accuracy:  0.6626
# Epoch 70, CIFAR-10 Batch 3:  Loss:  0.0101389
# Validation accuracy:  0.665
# Epoch 70, CIFAR-10 Batch 4:  Loss:  0.00954561
# Validation accuracy:  0.6602
# Epoch 70, CIFAR-10 Batch 5:  Loss:  0.0148979
# Validation accuracy:  0.6616
# Epoch 71, CIFAR-10 Batch 1:  Loss:  0.0107139
# Validation accuracy:  0.6628
# Epoch 71, CIFAR-10 Batch 2:  Loss:  0.0152554
# Validation accuracy:  0.6596
# Epoch 71, CIFAR-10 Batch 3:  Loss:  0.0106666
# Validation accuracy:  0.6662
# Epoch 71, CIFAR-10 Batch 4:  Loss:  0.00810769
# Validation accuracy:  0.661
# Epoch 71, CIFAR-10 Batch 5:  Loss:  0.0110512
# Validation accuracy:  0.6576
# Epoch 72, CIFAR-10 Batch 1:  Loss:  0.00816026
# Validation accuracy:  0.6688
# Epoch 72, CIFAR-10 Batch 2:  Loss:  0.0150482
# Validation accuracy:  0.6738
# Epoch 72, CIFAR-10 Batch 3:  Loss:  0.00899724
# Validation accuracy:  0.673
# Epoch 72, CIFAR-10 Batch 4:  Loss:  0.00683566
# Validation accuracy:  0.6636
# Epoch 72, CIFAR-10 Batch 5:  Loss:  0.00815292
# Validation accuracy:  0.662
# Epoch 73, CIFAR-10 Batch 1:  Loss:  0.00993693
# Validation accuracy:  0.6622
# Epoch 73, CIFAR-10 Batch 2:  Loss:  0.0122676
# Validation accuracy:  0.661
# Epoch 73, CIFAR-10 Batch 3:  Loss:  0.00844015
# Validation accuracy:  0.6674
# Epoch 73, CIFAR-10 Batch 4:  Loss:  0.00829634
# Validation accuracy:  0.6624
# Epoch 73, CIFAR-10 Batch 5:  Loss:  0.00845958
# Validation accuracy:  0.655
# Epoch 74, CIFAR-10 Batch 1:  Loss:  0.0106674
# Validation accuracy:  0.6642
# Epoch 74, CIFAR-10 Batch 2:  Loss:  0.0112755
# Validation accuracy:  0.6624
# Epoch 74, CIFAR-10 Batch 3:  Loss:  0.00968955
# Validation accuracy:  0.6684
# Epoch 74, CIFAR-10 Batch 4:  Loss:  0.00728643
# Validation accuracy:  0.6644
# Epoch 74, CIFAR-10 Batch 5:  Loss:  0.0104874
# Validation accuracy:  0.6638
# Epoch 75, CIFAR-10 Batch 1:  Loss:  0.00734707
# Validation accuracy:  0.671
# Epoch 75, CIFAR-10 Batch 2:  Loss:  0.00896124
# Validation accuracy:  0.6676
# Epoch 75, CIFAR-10 Batch 3:  Loss:  0.00849967
# Validation accuracy:  0.6654
# Epoch 75, CIFAR-10 Batch 4:  Loss:  0.00604366
# Validation accuracy:  0.662
# Epoch 75, CIFAR-10 Batch 5:  Loss:  0.00897523
# Validation accuracy:  0.6648
# Epoch 76, CIFAR-10 Batch 1:  Loss:  0.00840037
# Validation accuracy:  0.6686
# Epoch 76, CIFAR-10 Batch 2:  Loss:  0.00924806
# Validation accuracy:  0.6686
# Epoch 76, CIFAR-10 Batch 3:  Loss:  0.00821831
# Validation accuracy:  0.6666
# Epoch 76, CIFAR-10 Batch 4:  Loss:  0.0062806
# Validation accuracy:  0.6614
# Epoch 76, CIFAR-10 Batch 5:  Loss:  0.00809495
# Validation accuracy:  0.6664
# Epoch 77, CIFAR-10 Batch 1:  Loss:  0.00643672
# Validation accuracy:  0.6726
# Epoch 77, CIFAR-10 Batch 2:  Loss:  0.0125527
# Validation accuracy:  0.6666
# Epoch 77, CIFAR-10 Batch 3:  Loss:  0.00750064
# Validation accuracy:  0.662
# Epoch 77, CIFAR-10 Batch 4:  Loss:  0.00620878
# Validation accuracy:  0.6676
# Epoch 77, CIFAR-10 Batch 5:  Loss:  0.00862251
# Validation accuracy:  0.666
# Epoch 78, CIFAR-10 Batch 1:  Loss:  0.00613792
# Validation accuracy:  0.6702
# Epoch 78, CIFAR-10 Batch 2:  Loss:  0.00837337
# Validation accuracy:  0.6742
# Epoch 78, CIFAR-10 Batch 3:  Loss:  0.0102058
# Validation accuracy:  0.667
# Epoch 78, CIFAR-10 Batch 4:  Loss:  0.00791479
# Validation accuracy:  0.6594
# Epoch 78, CIFAR-10 Batch 5:  Loss:  0.00810393
# Validation accuracy:  0.6578
# Epoch 79, CIFAR-10 Batch 1:  Loss:  0.00615601
# Validation accuracy:  0.6732
# Epoch 79, CIFAR-10 Batch 2:  Loss:  0.00640298
# Validation accuracy:  0.6764
# Epoch 79, CIFAR-10 Batch 3:  Loss:  0.00860806
# Validation accuracy:  0.6648
# Epoch 79, CIFAR-10 Batch 4:  Loss:  0.00519526
# Validation accuracy:  0.667
# Epoch 79, CIFAR-10 Batch 5:  Loss:  0.00672748
# Validation accuracy:  0.6636
# Epoch 80, CIFAR-10 Batch 1:  Loss:  0.00551169
# Validation accuracy:  0.675
# Epoch 80, CIFAR-10 Batch 2:  Loss:  0.0109112
# Validation accuracy:  0.6754
# Epoch 80, CIFAR-10 Batch 3:  Loss:  0.00629644
# Validation accuracy:  0.6638
# Epoch 80, CIFAR-10 Batch 4:  Loss:  0.00935241
# Validation accuracy:  0.654
# Epoch 80, CIFAR-10 Batch 5:  Loss:  0.00990521
# Validation accuracy:  0.6666
# Epoch 81, CIFAR-10 Batch 1:  Loss:  0.00609916
# Validation accuracy:  0.6692
# Epoch 81, CIFAR-10 Batch 2:  Loss:  0.00946928
# Validation accuracy:  0.6708
# Epoch 81, CIFAR-10 Batch 3:  Loss:  0.00791012
# Validation accuracy:  0.6622
# Epoch 81, CIFAR-10 Batch 4:  Loss:  0.00637
# Validation accuracy:  0.668
# Epoch 81, CIFAR-10 Batch 5:  Loss:  0.00899231
# Validation accuracy:  0.6564
# Epoch 82, CIFAR-10 Batch 1:  Loss:  0.00473133
# Validation accuracy:  0.6644
# Epoch 82, CIFAR-10 Batch 2:  Loss:  0.00929216
# Validation accuracy:  0.666
# Epoch 82, CIFAR-10 Batch 3:  Loss:  0.00777079
# Validation accuracy:  0.6644
# Epoch 82, CIFAR-10 Batch 4:  Loss:  0.00685964
# Validation accuracy:  0.671
# Epoch 82, CIFAR-10 Batch 5:  Loss:  0.0110357
# Validation accuracy:  0.6572
# Epoch 83, CIFAR-10 Batch 1:  Loss:  0.00795474
# Validation accuracy:  0.6674
# Epoch 83, CIFAR-10 Batch 2:  Loss:  0.00735527
# Validation accuracy:  0.6664
# Epoch 83, CIFAR-10 Batch 3:  Loss:  0.00787973
# Validation accuracy:  0.6628
# Epoch 83, CIFAR-10 Batch 4:  Loss:  0.00495301
# Validation accuracy:  0.6686
# Epoch 83, CIFAR-10 Batch 5:  Loss:  0.00568342
# Validation accuracy:  0.665
# Epoch 84, CIFAR-10 Batch 1:  Loss:  0.00658486
# Validation accuracy:  0.6602
# Epoch 84, CIFAR-10 Batch 2:  Loss:  0.00636812
# Validation accuracy:  0.673
# Epoch 84, CIFAR-10 Batch 3:  Loss:  0.00580999
# Validation accuracy:  0.6678
# Epoch 84, CIFAR-10 Batch 4:  Loss:  0.00600771
# Validation accuracy:  0.6622
# Epoch 84, CIFAR-10 Batch 5:  Loss:  0.00498467
# Validation accuracy:  0.6664
# Epoch 85, CIFAR-10 Batch 1:  Loss:  0.00413114
# Validation accuracy:  0.67
# Epoch 85, CIFAR-10 Batch 2:  Loss:  0.00598717
# Validation accuracy:  0.6754
# Epoch 85, CIFAR-10 Batch 3:  Loss:  0.00490022
# Validation accuracy:  0.6648
# Epoch 85, CIFAR-10 Batch 4:  Loss:  0.00510511
# Validation accuracy:  0.6704
# Epoch 85, CIFAR-10 Batch 5:  Loss:  0.00590334
# Validation accuracy:  0.6628
# Epoch 86, CIFAR-10 Batch 1:  Loss:  0.00325258
# Validation accuracy:  0.6726
# Epoch 86, CIFAR-10 Batch 2:  Loss:  0.00511184
# Validation accuracy:  0.6738
# Epoch 86, CIFAR-10 Batch 3:  Loss:  0.00488378
# Validation accuracy:  0.6656
# Epoch 86, CIFAR-10 Batch 4:  Loss:  0.00612536
# Validation accuracy:  0.6582
# Epoch 86, CIFAR-10 Batch 5:  Loss:  0.00556307
# Validation accuracy:  0.655
# Epoch 87, CIFAR-10 Batch 1:  Loss:  0.00471623
# Validation accuracy:  0.6648
# Epoch 87, CIFAR-10 Batch 2:  Loss:  0.00480323
# Validation accuracy:  0.6682
# Epoch 87, CIFAR-10 Batch 3:  Loss:  0.0056647
# Validation accuracy:  0.6758
# Epoch 87, CIFAR-10 Batch 4:  Loss:  0.00391143
# Validation accuracy:  0.671
# Epoch 87, CIFAR-10 Batch 5:  Loss:  0.00574088
# Validation accuracy:  0.6614
# Epoch 88, CIFAR-10 Batch 1:  Loss:  0.00436156
# Validation accuracy:  0.6684
# Epoch 88, CIFAR-10 Batch 2:  Loss:  0.00435237
# Validation accuracy:  0.6722
# Epoch 88, CIFAR-10 Batch 3:  Loss:  0.00407213
# Validation accuracy:  0.668
# Epoch 88, CIFAR-10 Batch 4:  Loss:  0.00456969
# Validation accuracy:  0.6672
# Epoch 88, CIFAR-10 Batch 5:  Loss:  0.00405732
# Validation accuracy:  0.6634
# Epoch 89, CIFAR-10 Batch 1:  Loss:  0.00345976
# Validation accuracy:  0.6682
# Epoch 89, CIFAR-10 Batch 2:  Loss:  0.00341292
# Validation accuracy:  0.6704
# Epoch 89, CIFAR-10 Batch 3:  Loss:  0.00645292
# Validation accuracy:  0.67
# Epoch 89, CIFAR-10 Batch 4:  Loss:  0.00480404
# Validation accuracy:  0.6642
# Epoch 89, CIFAR-10 Batch 5:  Loss:  0.00437253
# Validation accuracy:  0.659
# Epoch 90, CIFAR-10 Batch 1:  Loss:  0.00613872
# Validation accuracy:  0.6648
# Epoch 90, CIFAR-10 Batch 2:  Loss:  0.00482658
# Validation accuracy:  0.6656
# Epoch 90, CIFAR-10 Batch 3:  Loss:  0.00433103
# Validation accuracy:  0.6732
# Epoch 90, CIFAR-10 Batch 4:  Loss:  0.00395603
# Validation accuracy:  0.6674
# Epoch 90, CIFAR-10 Batch 5:  Loss:  0.00407653
# Validation accuracy:  0.6604
# Epoch 91, CIFAR-10 Batch 1:  Loss:  0.00372306
# Validation accuracy:  0.6596
# Epoch 91, CIFAR-10 Batch 2:  Loss:  0.00664171
# Validation accuracy:  0.6684
# Epoch 91, CIFAR-10 Batch 3:  Loss:  0.00467392
# Validation accuracy:  0.6646
# Epoch 91, CIFAR-10 Batch 4:  Loss:  0.00323876
# Validation accuracy:  0.667
# Epoch 91, CIFAR-10 Batch 5:  Loss:  0.00395541
# Validation accuracy:  0.6648
# Epoch 92, CIFAR-10 Batch 1:  Loss:  0.00348372
# Validation accuracy:  0.67
# Epoch 92, CIFAR-10 Batch 2:  Loss:  0.00441691
# Validation accuracy:  0.6626
# Epoch 92, CIFAR-10 Batch 3:  Loss:  0.00387868
# Validation accuracy:  0.6768
# Epoch 92, CIFAR-10 Batch 4:  Loss:  0.0034307
# Validation accuracy:  0.6728
# Epoch 92, CIFAR-10 Batch 5:  Loss:  0.00438852
# Validation accuracy:  0.6668
# Epoch 93, CIFAR-10 Batch 1:  Loss:  0.00371089
# Validation accuracy:  0.6706
# Epoch 93, CIFAR-10 Batch 2:  Loss:  0.00515248
# Validation accuracy:  0.6618
# Epoch 93, CIFAR-10 Batch 3:  Loss:  0.00410342
# Validation accuracy:  0.6694
# Epoch 93, CIFAR-10 Batch 4:  Loss:  0.00417081
# Validation accuracy:  0.6652
# Epoch 93, CIFAR-10 Batch 5:  Loss:  0.00318758
# Validation accuracy:  0.6614
# Epoch 94, CIFAR-10 Batch 1:  Loss:  0.00337277
# Validation accuracy:  0.6708
# Epoch 94, CIFAR-10 Batch 2:  Loss:  0.00427354
# Validation accuracy:  0.6724
# Epoch 94, CIFAR-10 Batch 3:  Loss:  0.00507428
# Validation accuracy:  0.6696
# Epoch 94, CIFAR-10 Batch 4:  Loss:  0.00440319
# Validation accuracy:  0.6742
# Epoch 94, CIFAR-10 Batch 5:  Loss:  0.00270014
# Validation accuracy:  0.6596
# Epoch 95, CIFAR-10 Batch 1:  Loss:  0.00278357
# Validation accuracy:  0.6668
# Epoch 95, CIFAR-10 Batch 2:  Loss:  0.00342131
# Validation accuracy:  0.6754
# Epoch 95, CIFAR-10 Batch 3:  Loss:  0.00297931
# Validation accuracy:  0.667
# Epoch 95, CIFAR-10 Batch 4:  Loss:  0.00306785
# Validation accuracy:  0.6632
# Epoch 95, CIFAR-10 Batch 5:  Loss:  0.00437034
# Validation accuracy:  0.6646
# Epoch 96, CIFAR-10 Batch 1:  Loss:  0.00397057
# Validation accuracy:  0.664
# Epoch 96, CIFAR-10 Batch 2:  Loss:  0.00333744
# Validation accuracy:  0.6648
# Epoch 96, CIFAR-10 Batch 3:  Loss:  0.00343768
# Validation accuracy:  0.6702
# Epoch 96, CIFAR-10 Batch 4:  Loss:  0.00309346
# Validation accuracy:  0.6672
# Epoch 96, CIFAR-10 Batch 5:  Loss:  0.00331445
# Validation accuracy:  0.6654
# Epoch 97, CIFAR-10 Batch 1:  Loss:  0.00316909
# Validation accuracy:  0.6662
# Epoch 97, CIFAR-10 Batch 2:  Loss:  0.00476825
# Validation accuracy:  0.6664
# Epoch 97, CIFAR-10 Batch 3:  Loss:  0.00494154
# Validation accuracy:  0.6722
# Epoch 97, CIFAR-10 Batch 4:  Loss:  0.0029455
# Validation accuracy:  0.6652
# Epoch 97, CIFAR-10 Batch 5:  Loss:  0.00354308
# Validation accuracy:  0.6656
# Epoch 98, CIFAR-10 Batch 1:  Loss:  0.00289321
# Validation accuracy:  0.6586
# Epoch 98, CIFAR-10 Batch 2:  Loss:  0.00344992
# Validation accuracy:  0.6652
# Epoch 98, CIFAR-10 Batch 3:  Loss:  0.00409053
# Validation accuracy:  0.6614
# Epoch 98, CIFAR-10 Batch 4:  Loss:  0.00319099
# Validation accuracy:  0.6638
# Epoch 98, CIFAR-10 Batch 5:  Loss:  0.00292934
# Validation accuracy:  0.6608
# Epoch 99, CIFAR-10 Batch 1:  Loss:  0.00192448
# Validation accuracy:  0.6652
# Epoch 99, CIFAR-10 Batch 2:  Loss:  0.00340006
# Validation accuracy:  0.6738
# Epoch 99, CIFAR-10 Batch 3:  Loss:  0.00378886
# Validation accuracy:  0.6692
# Epoch 99, CIFAR-10 Batch 4:  Loss:  0.00240301
# Validation accuracy:  0.6634
# Epoch 99, CIFAR-10 Batch 5:  Loss:  0.00279876
# Validation accuracy:  0.6728
# Epoch 100, CIFAR-10 Batch 1:  Loss:  0.00321617
# Validation accuracy:  0.6706
# Epoch 100, CIFAR-10 Batch 2:  Loss:  0.0034636
# Validation accuracy:  0.6668
# Epoch 100, CIFAR-10 Batch 3:  Loss:  0.00421583
# Validation accuracy:  0.6658
# Epoch 100, CIFAR-10 Batch 4:  Loss:  0.00270321
# Validation accuracy:  0.6732
# Epoch 100, CIFAR-10 Batch 5:  Loss:  0.00468396
# Validation accuracy:  0.6634

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6595999777317048

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
